# %% [markdown]
# # Ghost Cars

# %%
# %run rallyman_internals.ipynb
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="187813">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## JCB initial proposal

# %%
white_dice_jcb = Dice(gears=    [1,2,3,4,5,6],
                      movements=[3,4,5,6,7,8])

black_dice_jcb = Dice(gears=    [1,2,3,4,5,6],
                      movements=[8,7,6,5,4,3])
                 
ghost_car_jcb = GhostCar(white_dice_jcb, black_dice_jcb)

show(plot_ghost_car_statistics(ghost_car_jcb))
# Out:
#   <div class="bk-root" id="9c8b890b-b0cb-4753-bfcd-6818baad6102" data-root-id="188171"></div>

# %% [markdown]
# ## Sky Zero proposal: Fibonacci gears

# %%
white_dice_sz = Dice(gears=    [1,3,3,5,5,6],
                     movements=[3,4,5,6,7,8])

black_dice_sz = Dice(gears=    [1,3,3,5,5,6],
                     movements=[8,7,6,5,4,3])
                 
ghost_car_sz = GhostCar(white_dice_sz, black_dice_sz)

show(plot_ghost_car_statistics(ghost_car_sz))
# Out:
#   <div class="bk-root" id="c8c27dab-bf69-4306-be8b-85a642ce5a39" data-root-id="193677"></div>

# %% [markdown]
# ## Nnexxus proposal (work in progress)

# %%
white_dice_nn = Dice(gears=    [1,2,3,4,5,6],
                     movements=[7,6,5,5,4,3])

black_dice_nn = Dice(gears=    [1,2,3,4,5,6],
                     movements=[3,4,5,5,6,7])
                 
ghost_car_nn = GhostCar(white_dice_nn, black_dice_nn)

show(plot_ghost_car_statistics(ghost_car_nn))
display(dice_image(white_dice_nn, dice_color="white", car_color="blue"))
display(dice_image(black_dice_nn, dice_color="black", car_color="blue"))
# Out:
#   <div class="bk-root" id="cc964e0c-fae6-4fe7-96cb-3ae3fbe800e2" data-root-id="204923"></div>
# <PIL.Image.Image image mode=RGBA size=1002x167 at 0x1AE65A94748>
# <PIL.Image.Image image mode=RGBA size=1002x167 at 0x1AE659E76D8>

# %% [markdown]
# # Some simple commands...

# %%
black_dice_jcb.roll()
# Out:
# DiceFace(gear=5, movement=4)

# %%
ghost_car_jcb.race(turns=15)
# Out:
# [DiceFace(gear=4, movement=5),
#  DiceFace(gear=1, movement=3),
#  DiceFace(gear=1, movement=8),
#  DiceFace(gear=1, movement=3),
#  DiceFace(gear=6, movement=3),
#  DiceFace(gear=3, movement=5),
#  DiceFace(gear=6, movement=3),
#  DiceFace(gear=4, movement=6),
#  DiceFace(gear=3, movement=6),
#  DiceFace(gear=2, movement=4),
#  DiceFace(gear=3, movement=6),
#  DiceFace(gear=4, movement=6),
#  DiceFace(gear=5, movement=4),
#  DiceFace(gear=5, movement=7),
#  DiceFace(gear=6, movement=3)]
